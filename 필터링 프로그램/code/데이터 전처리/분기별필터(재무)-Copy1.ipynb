# %%
import pandas as pd
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ### 데이터 로드

# %%
df = pd.read_csv("..\\..\\data\\분기별 재무.csv", encoding = "ms949")

# %% [markdown]
# ### 매출액은 연결과 개별을 구분지어 필터생성할 것이기 때문에 구분해준다

# %%
A = df[(df["Kind"] == "NFS-IFRS(C)") & (df["Item Name "] == "매출액(원)")]
df.loc[A.index, "Item Name "] = "매출액(연결)"

# %%
df.head()
# Out:
#     Symbol         Kind  Item Name            2015-01-31           2015-02-28  \
# 0  A005930  NFS-IFRS(C)     매출액(연결)   47,117,918,000,000   47,117,918,000,000
# 1  A005930  NFS-IFRS(S)      매출액(원)   31,689,206,000,000   31,689,206,000,000
# 2  A005930  NFS-IFRS(C)     영업이익(원)    5,979,367,000,000    5,979,367,000,000
# 3  A005930  NFS-IFRS(C)  지배주주순이익(원)    4,519,323,000,000    4,519,323,000,000
# 4  A005930  NFS-IFRS(C)      총자본(원)  167,619,307,000,000  167,619,307,000,000
#
#             2015-03-31           2015-04-30           2015-05-31  \
# 0   47,117,918,000,000   48,537,539,000,000   48,537,539,000,000
# 1   31,689,206,000,000   32,552,308,000,000   32,552,308,000,000
# 2    5,979,367,000,000    6,897,937,000,000    6,897,937,000,000
# 3    4,519,323,000,000    5,626,734,000,000    5,626,734,000,000
# 4  167,619,307,000,000  173,936,646,000,000  173,936,646,000,000
#
#             2015-06-30           2015-07-31  ...           2019-05-31  \
# 0   48,537,539,000,000   51,682,572,000,000  ...   56,127,104,000,000
# 1   32,552,308,000,000   35,820,499,000,000  ...   38,149,674,000,000
# 2    6,897,937,000,000    7,393,373,000,000  ...    6,597,065,000,000
# 3    5,626,734,000,000    5,306,104,000,000  ...    5,064,530,000,000
# 4  173,936,646,000,000  180,728,636,000,000  ...  257,747,033,000,000
#
#             2019-06-30           2019-07-31           2019-08-31  \
# 0   56,127,104,000,000   62,003,471,000,000   62,003,471,000,000
# 1   38,149,674,000,000   42,204,911,000,000   42,204,911,000,000
# 2    6,597,065,000,000    7,777,892,000,000    7,777,892,000,000
# 3    5,064,530,000,000    6,105,039,000,000    6,105,039,000,000
# 4  257,747,033,000,000  263,442,244,000,000  263,442,244,000,000
#
#             2019-09-30 2019-10-31 2019-11-30 2019-12-31 2020-01-31 2020-02-03
# 0   62,003,471,000,000        NaN        NaN        NaN        NaN        NaN
# 1   42,204,911,000,000        NaN        NaN        NaN        NaN        NaN
# 2    7,777,892,000,000        NaN        NaN        NaN        NaN        NaN
# 3    6,105,039,000,000        NaN        NaN        NaN        NaN        NaN
# 4  263,442,244,000,000        NaN        NaN        NaN        NaN        NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# ### 데이터의 계정이름을 사용하기 쉬운 계정이름으로 변환

# %%
계정명 = df["Item Name "].drop_duplicates().tolist()

# %%
바꿀계정명 = ["연결매출","매출액", "영업이익", "지배주주순이익", "총자본", "총부채", "자본금", "이익잉여금", 
                 "영업활동으로인한현금흐름", "투자활동으로인한현금흐름", "배당", "주가", "종가", "상장주식수"]

# %%
temp = {}

for 계정 in range(len(계정명)):
    temp[계정명[계정]] = 바꿀계정명[계정]
    print(계정명[계정]+ "     ->     " +  바꿀계정명[계정])
# Out:
# 매출액(연결)     ->     연결매출
# 매출액(원)     ->     매출액
# 영업이익(원)     ->     영업이익
# 지배주주순이익(원)     ->     지배주주순이익
# 총자본(원)     ->     총자본
# 총부채(원)     ->     총부채
# 자본금(원)     ->     자본금
# 이익잉여금(원)     ->     이익잉여금
# 영업활동으로인한현금흐름(원)     ->     영업활동으로인한현금흐름
# 투자활동으로인한현금흐름(원)     ->     투자활동으로인한현금흐름
# 수정DPS(보통주,현금)(원)     ->     배당
# 수정주가(원)     ->     주가
# 종가(원)     ->     종가
# 상장주식수(주)     ->     상장주식수

# %% [markdown]
# ### 바뀐 계정 할당

# %%
df = df.replace({"Item Name ": temp})

# %%
# 연결매출 판별하는데 사용한 Kind는 이제 필요가 없으므로 drop한다

# %%
df = df.drop("Kind", axis=1)

# %%
df.head()
# Out:
#     Symbol Item Name            2015-01-31           2015-02-28  \
# 0  A005930       연결매출   47,117,918,000,000   47,117,918,000,000
# 1  A005930        매출액   31,689,206,000,000   31,689,206,000,000
# 2  A005930       영업이익    5,979,367,000,000    5,979,367,000,000
# 3  A005930    지배주주순이익    4,519,323,000,000    4,519,323,000,000
# 4  A005930        총자본  167,619,307,000,000  167,619,307,000,000
#
#             2015-03-31           2015-04-30           2015-05-31  \
# 0   47,117,918,000,000   48,537,539,000,000   48,537,539,000,000
# 1   31,689,206,000,000   32,552,308,000,000   32,552,308,000,000
# 2    5,979,367,000,000    6,897,937,000,000    6,897,937,000,000
# 3    4,519,323,000,000    5,626,734,000,000    5,626,734,000,000
# 4  167,619,307,000,000  173,936,646,000,000  173,936,646,000,000
#
#             2015-06-30           2015-07-31           2015-08-31  ...  \
# 0   48,537,539,000,000   51,682,572,000,000   51,682,572,000,000  ...
# 1   32,552,308,000,000   35,820,499,000,000   35,820,499,000,000  ...
# 2    6,897,937,000,000    7,393,373,000,000    7,393,373,000,000  ...
# 3    5,626,734,000,000    5,306,104,000,000    5,306,104,000,000  ...
# 4  173,936,646,000,000  180,728,636,000,000  180,728,636,000,000  ...
#
#             2019-05-31           2019-06-30           2019-07-31  \
# 0   56,127,104,000,000   56,127,104,000,000   62,003,471,000,000
# 1   38,149,674,000,000   38,149,674,000,000   42,204,911,000,000
# 2    6,597,065,000,000    6,597,065,000,000    7,777,892,000,000
# 3    5,064,530,000,000    5,064,530,000,000    6,105,039,000,000
# 4  257,747,033,000,000  257,747,033,000,000  263,442,244,000,000
#
#             2019-08-31           2019-09-30 2019-10-31 2019-11-30 2019-12-31  \
# 0   62,003,471,000,000   62,003,471,000,000        NaN        NaN        NaN
# 1   42,204,911,000,000   42,204,911,000,000        NaN        NaN        NaN
# 2    7,777,892,000,000    7,777,892,000,000        NaN        NaN        NaN
# 3    6,105,039,000,000    6,105,039,000,000        NaN        NaN        NaN
# 4  263,442,244,000,000  263,442,244,000,000        NaN        NaN        NaN
#
#   2020-01-31 2020-02-03
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
#
# [5 rows x 64 columns]

# %%
# df 시간변환

# %%
df = df.set_index(['Symbol', "Item Name "])
시간변환 = pd.to_datetime(df.columns)
시간변환 = 시간변환.strftime("%Y-%m-%d")
시간변환 = 시간변환.rename("date")
df.columns = pd.to_datetime(시간변환)

# %%
# 데이터를 받은 후 프레임의 가장 마지막 컬럼(2020-01-31)은 비워져있고, 
# 마지막 컬럼 전년도의 컬럼(2019-12-31)은 비워져있거나 채워져있거나이다.
# 즉 전년도의 재무데이터는 발표를 한 경우와 하지 않은 경우로 나뉘어진다.
# 감사보고서 제출일이 3월 15일이기 때문에 3월 15일 이전에는 전년도 컬럼이 비워져있고, 이후에는 채워져 있을 것이다.
# 넉넉잡아 4월을 기준으로 판단하기로 한다.
# 따라서 현재 시점이 4월 이전인 경우에는 현재컬럼과 마지막 전년도 컬럼이 둘 다 비워져있고
# 현재 시점이 4월 이후인 경우에는 현재 컬럼만 비워져 있을 것이다. 

# 현재 컬럼과 마지막 전년도 컬럼이 둘 다 비워져 있는 경우에는 현재 컬럼을 없애기로 하는데
# 이는 마지막 컬럼시점과 현재 컬럼시점에 얻을 수 있는 데이터가 동일하기 때문에 필터링 조건에 왜곡이 나타나기 때문이다.

# 본 프로그램의 목표는 2019-12-31컬럼에 채워지는 데이터들은 해당 시점에 알 수 있는 가장 최근 데이터들을 나타내는 것
# 그런데 2019-12-31일에 알 수 있는 데이터들이 2020-1-31일에 알 수 있는 데이터들과 재무데이터의 경우 완전 동일함
# 완전 동일한 경우 증감폭 등이 0이 되기 때문에 동일한 하나의 컬럼은 빼 줘야 하는것.
# 따라서 4월 이전인 경우에 현재 칼럼을 없애버린다.

# %%
df
# Out:
# date                           2015-01-31           2015-02-28  \
# Symbol  Item Name
# A005930 연결매출           47,117,918,000,000   47,117,918,000,000
#         매출액            31,689,206,000,000   31,689,206,000,000
#         영업이익            5,979,367,000,000    5,979,367,000,000
#         지배주주순이익         4,519,323,000,000    4,519,323,000,000
#         총자본           167,619,307,000,000  167,619,307,000,000
#         총부채            59,631,070,000,000   59,631,070,000,000
#         자본금               897,514,000,000      897,514,000,000
#         이익잉여금         171,105,630,000,000  171,105,630,000,000
#         영업활동으로인한현금흐름    5,121,992,000,000    5,121,992,000,000
#         투자활동으로인한현금흐름     -228,222,000,000     -228,222,000,000
#         배당                            NaN                  NaN
#         주가                         27,300               27,140
#         종가                      1,365,000            1,357,000
#         상장주식수                 147,299,337          147,299,337
# A000660 연결매출            4,818,341,000,000    4,818,341,000,000
#         매출액             4,799,778,000,000    4,799,778,000,000
#         영업이익            1,588,530,000,000    1,588,530,000,000
#         지배주주순이익         1,295,730,000,000    1,295,730,000,000
#         총자본            19,125,736,000,000   19,125,736,000,000
#         총부채             8,267,177,000,000    8,267,177,000,000
#         자본금             3,657,652,000,000    3,657,652,000,000
#         이익잉여금          11,352,618,000,000   11,352,618,000,000
#         영업활동으로인한현금흐름    2,537,650,000,000    2,537,650,000,000
#         투자활동으로인한현금흐름   -2,027,076,000,000   -2,027,076,000,000
#         배당                            NaN                  NaN
#         주가                         47,650               46,600
#         종가                         47,650               46,600
#         상장주식수                 728,002,365          728,002,365
# A207940 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
# ...                                   ...                  ...
# A900180 종가                          2,950                3,310
#         상장주식수                  90,088,249           90,088,249
# A950010 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            690                  690
#         종가                            690                  690
#         상장주식수                   4,803,497            4,803,497
# A950070 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            NaN                  NaN
#         종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
#
# date                           2015-03-31           2015-04-30  \
# Symbol  Item Name
# A005930 연결매출           47,117,918,000,000   48,537,539,000,000
#         매출액            31,689,206,000,000   32,552,308,000,000
#         영업이익            5,979,367,000,000    6,897,937,000,000
#         지배주주순이익         4,519,323,000,000    5,626,734,000,000
#         총자본           167,619,307,000,000  173,936,646,000,000
#         총부채            59,631,070,000,000   57,754,240,000,000
#         자본금               897,514,000,000      897,514,000,000
#         이익잉여금         171,105,630,000,000  176,732,364,000,000
#         영업활동으로인한현금흐름    5,121,992,000,000   10,709,603,000,000
#         투자활동으로인한현금흐름     -228,222,000,000   -9,932,401,000,000
#         배당                            NaN                20.00
#         주가                         28,820               28,200
#         종가                      1,441,000            1,410,000
#         상장주식수                 147,299,337          147,299,337
# A000660 연결매출            4,818,341,000,000    4,638,579,000,000
#         매출액             4,799,778,000,000    4,641,958,000,000
#         영업이익            1,588,530,000,000    1,375,480,000,000
#         지배주주순이익         1,295,730,000,000    1,108,069,000,000
#         총자본            19,125,736,000,000   20,295,553,000,000
#         총부채             8,267,177,000,000    8,168,152,000,000
#         자본금             3,657,652,000,000    3,657,652,000,000
#         이익잉여금          11,352,618,000,000   12,459,056,000,000
#         영업활동으로인한현금흐름    2,537,650,000,000    2,148,740,000,000
#         투자활동으로인한현금흐름   -2,027,076,000,000   -1,771,208,000,000
#         배당                            NaN                  NaN
#         주가                         45,550               46,150
#         종가                         45,550               46,150
#         상장주식수                 728,002,365          728,002,365
# A207940 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
# ...                                   ...                  ...
# A900180 종가                          2,720                2,895
#         상장주식수                  90,088,249           90,088,249
# A950010 연결매출                          NaN                    0
#         매출액                           NaN                  NaN
#         영업이익                          NaN                    0
#         지배주주순이익                       NaN                    0
#         총자본                           NaN      544,637,835,000
#         총부채                           NaN      214,840,120,000
#         자본금                           NaN       26,294,735,000
#         이익잉여금                         NaN      -68,143,765,000
#         영업활동으로인한현금흐름                  NaN                    0
#         투자활동으로인한현금흐름                  NaN                    0
#         배당                            NaN                  NaN
#         주가                            690                  690
#         종가                            690                  690
#         상장주식수                   4,803,497            4,803,497
# A950070 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            NaN                  NaN
#         종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
#
# date                           2015-05-31           2015-06-30  \
# Symbol  Item Name
# A005930 연결매출           48,537,539,000,000   48,537,539,000,000
#         매출액            32,552,308,000,000   32,552,308,000,000
#         영업이익            6,897,937,000,000    6,897,937,000,000
#         지배주주순이익         5,626,734,000,000    5,626,734,000,000
#         총자본           173,936,646,000,000  173,936,646,000,000
#         총부채            57,754,240,000,000   57,754,240,000,000
#         자본금               897,514,000,000      897,514,000,000
#         이익잉여금         176,732,364,000,000  176,732,364,000,000
#         영업활동으로인한현금흐름   10,709,603,000,000   10,709,603,000,000
#         투자활동으로인한현금흐름   -9,932,401,000,000   -9,932,401,000,000
#         배당                          20.00                20.00
#         주가                         26,140               25,360
#         종가                      1,307,000            1,268,000
#         상장주식수                 147,299,337          147,299,337
# A000660 연결매출            4,638,579,000,000    4,638,579,000,000
#         매출액             4,641,958,000,000    4,641,958,000,000
#         영업이익            1,375,480,000,000    1,375,480,000,000
#         지배주주순이익         1,108,069,000,000    1,108,069,000,000
#         총자본            20,295,553,000,000   20,295,553,000,000
#         총부채             8,168,152,000,000    8,168,152,000,000
#         자본금             3,657,652,000,000    3,657,652,000,000
#         이익잉여금          12,459,056,000,000   12,459,056,000,000
#         영업활동으로인한현금흐름    2,148,740,000,000    2,148,740,000,000
#         투자활동으로인한현금흐름   -1,771,208,000,000   -1,771,208,000,000
#         배당                            NaN                  NaN
#         주가                         51,100               42,300
#         종가                         51,100               42,300
#         상장주식수                 728,002,365          728,002,365
# A207940 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
# ...                                   ...                  ...
# A900180 종가                          2,790                2,110
#         상장주식수                  90,088,249           90,088,249
# A950010 연결매출                            0                    0
#         매출액                           NaN                  NaN
#         영업이익                            0                    0
#         지배주주순이익                         0                    0
#         총자본               544,637,835,000      544,637,835,000
#         총부채               214,840,120,000      214,840,120,000
#         자본금                26,294,735,000       26,294,735,000
#         이익잉여금             -68,143,765,000      -68,143,765,000
#         영업활동으로인한현금흐름                    0                    0
#         투자활동으로인한현금흐름                    0                    0
#         배당                            NaN                  NaN
#         주가                            690                  690
#         종가                            690                  690
#         상장주식수                   4,803,497            4,803,497
# A950070 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            NaN                  NaN
#         종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
#
# date                           2015-07-31           2015-08-31  \
# Symbol  Item Name
# A005930 연결매출           51,682,572,000,000   51,682,572,000,000
#         매출액            35,820,499,000,000   35,820,499,000,000
#         영업이익            7,393,373,000,000    7,393,373,000,000
#         지배주주순이익         5,306,104,000,000    5,306,104,000,000
#         총자본           180,728,636,000,000  180,728,636,000,000
#         총부채            65,838,937,000,000   65,838,937,000,000
#         자본금               897,514,000,000      897,514,000,000
#         이익잉여금         181,889,556,000,000  181,889,556,000,000
#         영업활동으로인한현금흐름   11,873,815,000,000   11,873,815,000,000
#         투자활동으로인한현금흐름   -7,985,729,000,000   -7,985,729,000,000
#         배당                            NaN                  NaN
#         주가                         23,700               21,780
#         종가                      1,185,000            1,089,000
#         상장주식수                 147,299,337          147,299,337
# A000660 연결매출            4,925,034,000,000    4,925,034,000,000
#         매출액             4,883,261,000,000    4,883,261,000,000
#         영업이익            1,383,215,000,000    1,383,215,000,000
#         지배주주순이익         1,048,307,000,000    1,048,307,000,000
#         총자본            20,766,327,000,000   20,766,327,000,000
#         총부채             8,575,813,000,000    8,575,813,000,000
#         자본금             3,657,652,000,000    3,657,652,000,000
#         이익잉여금          13,505,758,000,000   13,505,758,000,000
#         영업활동으로인한현금흐름    2,189,805,000,000    2,189,805,000,000
#         투자활동으로인한현금흐름   -1,988,293,000,000   -1,988,293,000,000
#         배당                            NaN                  NaN
#         주가                         37,100               35,800
#         종가                         37,100               35,800
#         상장주식수                 728,002,365          728,002,365
# A207940 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
# ...                                   ...                  ...
# A900180 종가                          2,340                2,055
#         상장주식수                  90,088,249           90,088,249
# A950010 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            690                  690
#         종가                            690                  690
#         상장주식수                   4,803,497            4,803,497
# A950070 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            NaN                  NaN
#         종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
#
# date                           2015-09-30           2015-10-31  ...  \
# Symbol  Item Name                                               ...
# A005930 연결매출           51,682,572,000,000   53,315,453,000,000  ...
#         매출액            35,820,499,000,000   35,143,032,000,000  ...
#         영업이익            7,393,373,000,000    6,142,765,000,000  ...
#         지배주주순이익         5,306,104,000,000    3,242,467,000,000  ...
#         총자본           180,728,636,000,000  179,059,805,000,000  ...
#         총부채            65,838,937,000,000   63,119,716,000,000  ...
#         자본금               897,514,000,000      897,514,000,000  ...
#         이익잉여금         181,889,556,000,000  185,132,014,000,000  ...
#         영업활동으로인한현금흐름   11,873,815,000,000   12,356,351,000,000  ...
#         투자활동으로인한현금흐름   -7,985,729,000,000   -9,021,435,000,000  ...
#         배당                            NaN               400.00  ...
#         주가                         22,680               27,440  ...
#         종가                      1,134,000            1,372,000  ...
#         상장주식수                 147,299,337          147,299,337  ...
# A000660 연결매출            4,925,034,000,000    4,416,044,000,000  ...
#         매출액             4,883,261,000,000    4,455,795,000,000  ...
#         영업이익            1,383,215,000,000      988,875,000,000  ...
#         지배주주순이익         1,048,307,000,000      870,250,000,000  ...
#         총자본            20,766,327,000,000   21,387,703,000,000  ...
#         총부채             8,575,813,000,000    8,290,203,000,000  ...
#         자본금             3,657,652,000,000    3,657,652,000,000  ...
#         이익잉여금          13,505,758,000,000   14,358,988,000,000  ...
#         영업활동으로인한현금흐름    2,189,805,000,000    2,443,325,000,000  ...
#         투자활동으로인한현금흐름   -1,988,293,000,000   -1,338,953,000,000  ...
#         배당                            NaN               500.00  ...
#         주가                         33,550               30,700  ...
#         종가                         33,550               30,700  ...
#         상장주식수                 728,002,365          728,002,365  ...
# A207940 연결매출                          NaN                    0  ...
#         매출액                           NaN                    0  ...
# ...                                   ...                  ...  ...
# A900180 종가                          1,915                2,690  ...
#         상장주식수                  90,088,249           90,088,249  ...
# A950010 연결매출                          NaN                  NaN  ...
#         매출액                           NaN                  NaN  ...
#         영업이익                          NaN                  NaN  ...
#         지배주주순이익                       NaN                  NaN  ...
#         총자본                           NaN                  NaN  ...
#         총부채                           NaN                  NaN  ...
#         자본금                           NaN                  NaN  ...
#         이익잉여금                         NaN                  NaN  ...
#         영업활동으로인한현금흐름                  NaN                  NaN  ...
#         투자활동으로인한현금흐름                  NaN                  NaN  ...
#         배당                            NaN                  NaN  ...
#         주가                            690                1,300  ...
#         종가                            690                1,300  ...
#         상장주식수                   4,803,497            4,803,497  ...
# A950070 연결매출                          NaN                  NaN  ...
#         매출액                           NaN                  NaN  ...
#         영업이익                          NaN                  NaN  ...
#         지배주주순이익                       NaN                  NaN  ...
#         총자본                           NaN                  NaN  ...
#         총부채                           NaN                  NaN  ...
#         자본금                           NaN                  NaN  ...
#         이익잉여금                         NaN                  NaN  ...
#         영업활동으로인한현금흐름                  NaN                  NaN  ...
#         투자활동으로인한현금흐름                  NaN                  NaN  ...
#         배당                            NaN                  NaN  ...
#         주가                            NaN                  NaN  ...
#         종가                            NaN                  NaN  ...
#         상장주식수                         NaN                  NaN  ...
#
# date                           2019-05-31           2019-06-30  \
# Symbol  Item Name
# A005930 연결매출           56,127,104,000,000   56,127,104,000,000
#         매출액            38,149,674,000,000   38,149,674,000,000
#         영업이익            6,597,065,000,000    6,597,065,000,000
#         지배주주순이익         5,064,530,000,000    5,064,530,000,000
#         총자본           257,747,033,000,000  257,747,033,000,000
#         총부채            85,193,101,000,000   85,193,101,000,000
#         자본금               897,514,000,000      897,514,000,000
#         이익잉여금         248,060,958,000,000  248,060,958,000,000
#         영업활동으로인한현금흐름    6,594,865,000,000    6,594,865,000,000
#         투자활동으로인한현금흐름   -3,284,060,000,000   -3,284,060,000,000
#         배당                         354.00               354.00
#         주가                         42,500               47,000
#         종가                         42,500               47,000
#         상장주식수               5,969,782,550        5,969,782,550
# A000660 연결매출            6,452,201,000,000    6,452,201,000,000
#         매출액             5,995,713,000,000    5,995,713,000,000
#         영업이익              637,630,000,000      637,630,000,000
#         지배주주순이익           535,529,000,000      535,529,000,000
#         총자본            47,710,787,000,000   47,710,787,000,000
#         총부채            15,321,477,000,000   15,321,477,000,000
#         자본금             3,657,652,000,000    3,657,652,000,000
#         이익잉여금          42,634,568,000,000   42,634,568,000,000
#         영업활동으로인한현금흐름   -1,228,201,000,000   -1,228,201,000,000
#         투자활동으로인한현금흐름     -228,136,000,000     -228,136,000,000
#         배당                            NaN                  NaN
#         주가                         65,300               69,500
#         종가                         65,300               69,500
#         상장주식수                 728,002,365          728,002,365
# A207940 연결매출                          NaN                  NaN
#         매출액                78,081,654,900       78,081,654,900
# ...                                   ...                  ...
# A900180 종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
# A950010 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            NaN                  NaN
#         종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
# A950070 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            NaN                  NaN
#         종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
#
# date                           2019-07-31           2019-08-31  \
# Symbol  Item Name
# A005930 연결매출           62,003,471,000,000   62,003,471,000,000
#         매출액            42,204,911,000,000   42,204,911,000,000
#         영업이익            7,777,892,000,000    7,777,892,000,000
#         지배주주순이익         6,105,039,000,000    6,105,039,000,000
#         총자본           263,442,244,000,000  263,442,244,000,000
#         총부채            89,943,741,000,000   89,943,741,000,000
#         자본금               897,514,000,000      897,514,000,000
#         이익잉여금         251,761,348,000,000  251,761,348,000,000
#         영업활동으로인한현금흐름   13,826,599,000,000   13,826,599,000,000
#         투자활동으로인한현금흐름  -12,933,588,000,000  -12,933,588,000,000
#         배당                         354.00               354.00
#         주가                         45,350               44,000
#         종가                         45,350               44,000
#         상장주식수               5,969,782,550        5,969,782,550
# A000660 연결매출            6,838,766,000,000    6,838,766,000,000
#         매출액             6,396,077,000,000    6,396,077,000,000
#         영업이익              472,561,000,000      472,561,000,000
#         지배주주순이익           493,201,000,000      493,201,000,000
#         총자본            48,266,226,000,000   48,266,226,000,000
#         총부채            15,405,525,000,000   15,405,525,000,000
#         자본금             3,657,652,000,000    3,657,652,000,000
#         이익잉여금          43,122,640,000,000   43,122,640,000,000
#         영업활동으로인한현금흐름    2,497,054,000,000    2,497,054,000,000
#         투자활동으로인한현금흐름   -3,147,713,000,000   -3,147,713,000,000
#         배당                            NaN                  NaN
#         주가                         76,900               77,400
#         종가                         76,900               77,400
#         상장주식수                 728,002,365          728,002,365
# A207940 연결매출                          NaN                  NaN
#         매출액               184,817,914,250      184,817,914,250
# ...                                   ...                  ...
# A900180 종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
# A950010 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            NaN                  NaN
#         종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
# A950070 연결매출                          NaN                  NaN
#         매출액                           NaN                  NaN
#         영업이익                          NaN                  NaN
#         지배주주순이익                       NaN                  NaN
#         총자본                           NaN                  NaN
#         총부채                           NaN                  NaN
#         자본금                           NaN                  NaN
#         이익잉여금                         NaN                  NaN
#         영업활동으로인한현금흐름                  NaN                  NaN
#         투자활동으로인한현금흐름                  NaN                  NaN
#         배당                            NaN                  NaN
#         주가                            NaN                  NaN
#         종가                            NaN                  NaN
#         상장주식수                         NaN                  NaN
#
# date                           2019-09-30     2019-10-31     2019-11-30  \
# Symbol  Item Name
# A005930 연결매출           62,003,471,000,000            NaN            NaN
#         매출액            42,204,911,000,000            NaN            NaN
#         영업이익            7,777,892,000,000            NaN            NaN
#         지배주주순이익         6,105,039,000,000            NaN            NaN
#         총자본           263,442,244,000,000            NaN            NaN
#         총부채            89,943,741,000,000            NaN            NaN
#         자본금               897,514,000,000            NaN            NaN
#         이익잉여금         251,761,348,000,000            NaN            NaN
#         영업활동으로인한현금흐름   13,826,599,000,000            NaN            NaN
#         투자활동으로인한현금흐름  -12,933,588,000,000            NaN            NaN
#         배당                         354.00            NaN            NaN
#         주가                         49,050         50,400         50,300
#         종가                         49,050         50,400         50,300
#         상장주식수               5,969,782,550  5,969,782,550  5,969,782,550
# A000660 연결매출            6,838,766,000,000            NaN            NaN
#         매출액             6,396,077,000,000            NaN            NaN
#         영업이익              472,561,000,000            NaN            NaN
#         지배주주순이익           493,201,000,000            NaN            NaN
#         총자본            48,266,226,000,000            NaN            NaN
#         총부채            15,405,525,000,000            NaN            NaN
#         자본금             3,657,652,000,000            NaN            NaN
#         이익잉여금          43,122,640,000,000            NaN            NaN
#         영업활동으로인한현금흐름    2,497,054,000,000            NaN            NaN
#         투자활동으로인한현금흐름   -3,147,713,000,000            NaN            NaN
#         배당                            NaN            NaN            NaN
#         주가                         82,200         82,000         80,900
#         종가                         82,200         82,000         80,900
#         상장주식수                 728,002,365    728,002,365    728,002,365
# A207940 연결매출                          NaN            NaN            NaN
#         매출액               184,817,914,250            NaN            NaN
# ...                                   ...            ...            ...
# A900180 종가                            NaN            NaN            NaN
#         상장주식수                         NaN            NaN            NaN
# A950010 연결매출                          NaN            NaN            NaN
#         매출액                           NaN            NaN            NaN
#         영업이익                          NaN            NaN            NaN
#         지배주주순이익                       NaN            NaN            NaN
#         총자본                           NaN            NaN            NaN
#         총부채                           NaN            NaN            NaN
#         자본금                           NaN            NaN            NaN
#         이익잉여금                         NaN            NaN            NaN
#         영업활동으로인한현금흐름                  NaN            NaN            NaN
#         투자활동으로인한현금흐름                  NaN            NaN            NaN
#         배당                            NaN            NaN            NaN
#         주가                            NaN            NaN            NaN
#         종가                            NaN            NaN            NaN
#         상장주식수                         NaN            NaN            NaN
# A950070 연결매출                          NaN            NaN            NaN
#         매출액                           NaN            NaN            NaN
#         영업이익                          NaN            NaN            NaN
#         지배주주순이익                       NaN            NaN            NaN
#         총자본                           NaN            NaN            NaN
#         총부채                           NaN            NaN            NaN
#         자본금                           NaN            NaN            NaN
#         이익잉여금                         NaN            NaN            NaN
#         영업활동으로인한현금흐름                  NaN            NaN            NaN
#         투자활동으로인한현금흐름                  NaN            NaN            NaN
#         배당                            NaN            NaN            NaN
#         주가                            NaN            NaN            NaN
#         종가                            NaN            NaN            NaN
#         상장주식수                         NaN            NaN            NaN
#
# date                     2019-12-31     2020-01-31     2020-02-03
# Symbol  Item Name
# A005930 연결매출                    NaN            NaN            NaN
#         매출액                     NaN            NaN            NaN
#         영업이익                    NaN            NaN            NaN
#         지배주주순이익                 NaN            NaN            NaN
#         총자본                     NaN            NaN            NaN
#         총부채                     NaN            NaN            NaN
#         자본금                     NaN            NaN            NaN
#         이익잉여금                   NaN            NaN            NaN
#         영업활동으로인한현금흐름            NaN            NaN            NaN
#         투자활동으로인한현금흐름            NaN            NaN            NaN
#         배당                      NaN            NaN            NaN
#         주가                   55,800         56,400         57,200
#         종가                   55,800         56,400         57,200
#         상장주식수         5,969,782,550  5,969,782,550  5,969,782,550
# A000660 연결매출                    NaN            NaN            NaN
#         매출액                     NaN            NaN            NaN
#         영업이익                    NaN            NaN            NaN
#         지배주주순이익                 NaN            NaN            NaN
#         총자본                     NaN            NaN            NaN
#         총부채                     NaN            NaN            NaN
#         자본금                     NaN            NaN            NaN
#         이익잉여금                   NaN            NaN            NaN
#         영업활동으로인한현금흐름            NaN            NaN            NaN
#         투자활동으로인한현금흐름            NaN            NaN            NaN
#         배당                      NaN            NaN            NaN
#         주가                   94,100         93,500         94,700
#         종가                   94,100         93,500         94,700
#         상장주식수           728,002,365    728,002,365    728,002,365
# A207940 연결매출                    NaN            NaN            NaN
#         매출액                     NaN            NaN            NaN
# ...                             ...            ...            ...
# A900180 종가                      NaN            NaN            NaN
#         상장주식수                   NaN            NaN            NaN
# A950010 연결매출                    NaN            NaN            NaN
#         매출액                     NaN            NaN            NaN
#         영업이익                    NaN            NaN            NaN
#         지배주주순이익                 NaN            NaN            NaN
#         총자본                     NaN            NaN            NaN
#         총부채                     NaN            NaN            NaN
#         자본금                     NaN            NaN            NaN
#         이익잉여금                   NaN            NaN            NaN
#         영업활동으로인한현금흐름            NaN            NaN            NaN
#         투자활동으로인한현금흐름            NaN            NaN            NaN
#         배당                      NaN            NaN            NaN
#         주가                      NaN            NaN            NaN
#         종가                      NaN            NaN            NaN
#         상장주식수                   NaN            NaN            NaN
# A950070 연결매출                    NaN            NaN            NaN
#         매출액                     NaN            NaN            NaN
#         영업이익                    NaN            NaN            NaN
#         지배주주순이익                 NaN            NaN            NaN
#         총자본                     NaN            NaN            NaN
#         총부채                     NaN            NaN            NaN
#         자본금                     NaN            NaN            NaN
#         이익잉여금                   NaN            NaN            NaN
#         영업활동으로인한현금흐름            NaN            NaN            NaN
#         투자활동으로인한현금흐름            NaN            NaN            NaN
#         배당                      NaN            NaN            NaN
#         주가                      NaN            NaN            NaN
#         종가                      NaN            NaN            NaN
#         상장주식수                   NaN            NaN            NaN
#
# [40824 rows x 62 columns]

# %%
if df.columns[-1].month < 4:
    df = df.drop(df.columns[-1], axis=1)
else:
    pass

# %%
df.head()
# Out:
# date                     2014-12-31       2015-12-31       2016-12-31  \
# Symbol  Item Name
# A005930 연결매출        206,205,987,000  200,653,482,000  201,866,745,000
#         매출액         137,825,547,000  135,205,045,000  133,947,204,000
#         영업이익         25,025,071,000   26,413,442,000   29,240,672,000
#         지배주주순이익      23,082,499,000   18,694,628,000   22,415,655,000
#         총자본         168,088,188,000  179,059,805,000  192,963,033,000
#
# date                     2017-12-31       2018-12-31 2019-12-31
# Symbol  Item Name
# A005930 연결매출        239,575,376,000  243,771,415,000        NaN
#         매출액         161,915,007,000  170,381,870,000        NaN
#         영업이익         53,645,038,000   58,886,669,000        NaN
#         지배주주순이익      41,344,569,000   43,890,877,000        NaN
#         총자본         214,491,428,000  247,753,177,000        NaN

# %% [markdown]
# ### 인덱스를 회사 - 시간의 이중 인덱스 변경. 컬럼은 재무 지표들로 변경

# %%
df = df.stack().swaplevel().unstack()

# %%
df.head()
# Out:
# Item Name                       매출액        배당          상장주식수             연결매출  \
# Symbol  date
# A005930 2014-12-31  137,825,547,000    400.00    147,299,337  206,205,987,000
#         2015-12-31  135,205,045,000    420.00    147,299,337  200,653,482,000
#         2016-12-31  133,947,204,000    570.00    140,679,337  201,866,745,000
#         2017-12-31  161,915,007,000    850.00    129,098,494  239,575,376,000
#         2018-12-31  170,381,870,000  1,416.00  5,969,782,550  243,771,415,000
#
# Item Name                     영업이익    영업활동으로인한현금흐름            이익잉여금  \
# Symbol  date
# A005930 2014-12-31  25,025,071,000  36,975,389,000  169,529,604,000
#         2015-12-31  26,413,442,000  40,061,761,000  185,132,014,000
#         2016-12-31  29,240,672,000  47,385,644,000  193,086,317,000
#         2017-12-31  53,645,038,000  62,162,041,000  215,811,200,000
#         2018-12-31  58,886,669,000  67,031,863,000  242,698,956,000
#
# Item Name                   자본금         종가      주가         지배주주순이익  \
# Symbol  date
# A005930 2014-12-31  897,514,000  1,327,000  26,540  23,082,499,000
#         2015-12-31  897,514,000  1,260,000  25,200  18,694,628,000
#         2016-12-31  897,514,000  1,802,000  36,040  22,415,655,000
#         2017-12-31  897,514,000  2,548,000  50,960  41,344,569,000
#         2018-12-31  897,514,000     38,700  38,700  43,890,877,000
#
# Item Name                      총부채              총자본     투자활동으로인한현금흐름
# Symbol  date
# A005930 2014-12-31  62,334,770,000  168,088,188,000  -32,806,408,000
#         2015-12-31  63,119,716,000  179,059,805,000  -27,167,787,000
#         2016-12-31  69,211,291,000  192,963,033,000  -29,658,675,000
#         2017-12-31  87,260,662,000  214,491,428,000  -49,385,216,000
#         2018-12-31  91,604,067,000  247,753,177,000  -52,240,453,000

# %% [markdown]
# ### df type 실수로 변환

# %%
for 계정 in df.columns:
    df[계정] = df[계정].str.replace(',', "")

df = df.astype(float)

# %%
# 데이터들의 년도를 미뤄주는 함수. 예를 들어 lag_year가 1년이면 1년전의 데이터를 가져오겠다는 뜻!! 한번 실행해보길
def lag_year(df, lag_year):
    copy_df = df.copy()
    lagged_df = copy_df.shift(lag_year)
    lag_index_list = []
    for index in df.columns:
        lag_index = index + " " + str(lag_year) + "Y lag"
        lag_index_list.append(lag_index)
    
    lagged_df.columns = lag_index_list
    
    return lagged_df

# %%
# 3월 15일을 기준으로 사용할 수 있는 재무데이터의 년도가 다름. 3월 전에는 전전년도의 재무데이터를 사용가능하지만
# 4월부터는 전년도 재무데이터를 사용할 수 있음
# 마찬가지로 이해가 안 된다면 실행시켜보길 권함!

def assign_announcement_year(df):
    copy_df = df.copy()
    
    # df 의 시간을 거슬러 올라가면서
    for time in reversed(copy_df.index):

        month = time.month
        day = time.day
        
        try:
            
            # 만약 해당 월이 4월 이상이라면
            if month > 3:
                
                ref_time = time- relativedelta(years = 1) # 작년 12월 데이터를 카피한다
                copy_df.loc[time] = copy_df.loc[ref_time]

                
            else:
                print("이때 언제 해당?")
                ref_time = time- relativedelta(years = 1) - relativedelta(months = month-1) - relativedelta(days = day) 
                copy_df.loc[time] = copy_df.loc[ref_time]                

        except Exception as e:
            copy_df.loc[time] = None
            pass
    
    return copy_df

# %% [markdown]
# ### 시가총액과 ROE, 영업이익률 생성

# %%
df["시가총액"] = df["종가"] * df["상장주식수"]
df["ROE"] = df["지배주주순이익"] /  df["총자본"]
df["영업이익률"] = df["영업이익"] / df["매출액"]

# %%
company = 'A005930'
## 이 부분이 복잡해보이는데 복사해서 밖으로 빼서 별도의 셀에서 한 행씩 실행시켜보면 이해가 됨

 # 회사의 데이터를 가져와서
temp = df.loc[company] 
# 즉시 알 수 있는 주식 데이터들만을 뽑아온 후
stock_data = df.loc[company][["주가", "상장주식수", "시가총액"]]
# 전년도에 대한 감사보고서 제출일이 3월 15일 이므로 3월을 기준으로 이전이라면 2년전의 데이터, 이후라면 1년전의 데이터 사용
temp = assign_announcement_year(temp)
# 필터 조건을 위한 전년도 데이터들을 생성하고
lag_1Y = lag_year(temp, 1)
lag_2Y = lag_year(temp, 2)
lag_3Y = lag_year(temp, 3)
lag_4Y = lag_year(temp, 4)
# 이를 합친다
temp = pd.concat([temp, lag_1Y, lag_2Y, lag_3Y, lag_4Y], axis = 1)

# 즉시 알 수 있는 stock data들도 재무데이터들과 마찬가지로 미뤄졌으므로, 다시 원래 데이터를 할당한다
temp[stock_data.columns]= stock_data

# temp를 밖에서 빼서 한번씩 실행하면 이해가 될거임!

# %%
temp
# Out:
#                      매출액      배당         상장주식수          연결매출          영업이익  \
# date
# 2014-12-31           NaN     NaN  1.472993e+08           NaN           NaN
# 2015-12-31  1.378255e+11   400.0  1.472993e+08  2.062060e+11  2.502507e+10
# 2016-12-31  1.352050e+11   420.0  1.406793e+08  2.006535e+11  2.641344e+10
# 2017-12-31  1.339472e+11   570.0  1.290985e+08  2.018667e+11  2.924067e+10
# 2018-12-31  1.619150e+11   850.0  5.969783e+09  2.395754e+11  5.364504e+10
# 2019-12-31  1.703819e+11  1416.0  5.969783e+09  2.437714e+11  5.888667e+10
#
#             영업활동으로인한현금흐름         이익잉여금          자본금         종가       주가  ...  \
# date                                                                     ...
# 2014-12-31           NaN           NaN          NaN        NaN  26540.0  ...
# 2015-12-31  3.697539e+10  1.695296e+11  897514000.0  1327000.0  25200.0  ...
# 2016-12-31  4.006176e+10  1.851320e+11  897514000.0  1260000.0  36040.0  ...
# 2017-12-31  4.738564e+10  1.930863e+11  897514000.0  1802000.0  50960.0  ...
# 2018-12-31  6.216204e+10  2.158112e+11  897514000.0  2548000.0  38700.0  ...
# 2019-12-31  6.703186e+10  2.426990e+11  897514000.0    38700.0  55800.0  ...
#
#              자본금 4Y lag  종가 4Y lag  주가 4Y lag  지배주주순이익 4Y lag    총부채 4Y lag  \
# date
# 2014-12-31          NaN        NaN        NaN             NaN           NaN
# 2015-12-31          NaN        NaN        NaN             NaN           NaN
# 2016-12-31          NaN        NaN        NaN             NaN           NaN
# 2017-12-31          NaN        NaN        NaN             NaN           NaN
# 2018-12-31          NaN        NaN        NaN             NaN           NaN
# 2019-12-31  897514000.0  1327000.0    26540.0    2.308250e+10  6.233477e+10
#
#               총자본 4Y lag  투자활동으로인한현금흐름 4Y lag   시가총액 4Y lag  ROE 4Y lag  \
# date
# 2014-12-31           NaN                  NaN           NaN         NaN
# 2015-12-31           NaN                  NaN           NaN         NaN
# 2016-12-31           NaN                  NaN           NaN         NaN
# 2017-12-31           NaN                  NaN           NaN         NaN
# 2018-12-31           NaN                  NaN           NaN         NaN
# 2019-12-31  1.680882e+11        -3.280641e+10  1.954662e+14    0.137324
#
#             영업이익률 4Y lag
# date
# 2014-12-31           NaN
# 2015-12-31           NaN
# 2016-12-31           NaN
# 2017-12-31           NaN
# 2018-12-31           NaN
# 2019-12-31      0.181571
#
# [6 rows x 85 columns]

# %%
# temp의 모양을 살펴보면 위와 같음.
# 즉 아래함수의 윗 부분은 해당 시점에 알 수 있는 가장 최신 데이터들로 바꿔주는 역할을 해줌

# %% [markdown]
# ## 필터링 조건 생성부

# %%
# 회사 리스트
company_list = df.index.levels[0]

# %%
new_data = []
for company in company_list:
    ## 이 부분이 복잡해보이는데 복사해서 밖으로 빼서 별도의 셀에서 한 행씩 실행시켜보면 이해가 됨
    
     # 회사의 데이터를 가져와서
    temp = df.loc[company] 
    # 즉시 알 수 있는 주식 데이터들만을 뽑아온 후
    stock_data = df.loc[company][["주가", "상장주식수", "시가총액"]]
    # 전년도에 대한 감사보고서 제출일이 3월 15일 이므로 3월을 기준으로 이전이라면 2년전의 데이터, 이후라면 1년전의 데이터 사용
    temp = assign_announcement_year(temp)
    # 필터 조건을 위한 전년도 데이터들을 생성하고
    lag_1Y = lag_year(temp, 1)
    lag_2Y = lag_year(temp, 2)
    lag_3Y = lag_year(temp, 3)
    lag_4Y = lag_year(temp, 4)
    # 이를 합친다
    temp = pd.concat([temp, lag_1Y, lag_2Y, lag_3Y, lag_4Y], axis = 1)
    
    # 즉시 알 수 있는 stock data들도 재무데이터들과 마찬가지로 미뤄졌으므로, 다시 원래 데이터를 할당한다
    temp[stock_data.columns]= stock_data
    
    # temp를 밖에서 빼서 한번씩 실행하면 이해가 될거임!
    

    # 2020년 2월 현재 알 수 있는 회사들의 재무데이터는 2019년 데이터가 아닌 2018년 데이터이다.
    # 2019년의 감사보고서의 제출 마감일은 2019년 3월 15일 까지로, 넉넉잡아 2019년 4월 1일부터는 감사보고서의
    # 데이터들을 사용할 수 있다.
    
    # 즉 정리하자면 2020년 2월 현재 회사에 대한 가장 최근 재무데이터들은 2018년 데이터들이고, 2019년 데이터가 아니다.
    # 2020년 4월이 된다면 활용할 수 있는 가장 최근 재무데이터들은 2019년 데이터이다.
    # 4월을 기점으로 이러한 시간의 변동이 일어나게 된다.
    

    
    ## 포괄손익계산서
    # 매출액 100억이상
    # 매출액은 단위가 (천원)
    temp["매출액 100억 이상"] = temp["매출액"] > 10000000
    
    #영업이익 3개년 모두 0 이상
    temp["영업이익 3년동안 0 이상"] = (temp["영업이익"] > 0) & (temp["영업이익 1Y lag"] > 0) & (temp["영업이익 2Y lag"] > 0)
    
    # 영업이익률 계속해서 증가
    temp["영업이익률 3년동안 증가"] = (temp["영업이익률"] > temp["영업이익률 1Y lag"]) &  (temp["영업이익률"] > temp["영업이익률 2Y lag"]) &  (temp["영업이익률 1Y lag"] > temp["영업이익률 2Y lag"])
    
    # 매출액 3년 동안 증가
    
    temp["매출액 3년동안 증가"] = (temp["매출액"] > temp["매출액 1Y lag"]) &  (temp["매출액"] > temp["매출액 2Y lag"]) &  (temp["매출액 1Y lag"] > temp["매출액 2Y lag"])
    
  
    # 시가총액 비율
    temp["순이익시총비율 0.1이상"] = (temp["지배주주순이익"] / temp["시가총액"])  > 0.1
    temp["영업이익시총비율 0.1이상"] = (temp["영업이익"] / temp["시가총액"]) > 0.1
    
    
    
    ## 재무상태표
    # 자본잠식
    temp["자본잠식 없음"] = temp["총자본"] > 0
    
    # 부채비율
    temp["부채비율"] = temp["총부채"] / temp["총자본"]
    temp["부채비율 150% 이하"] = temp["부채비율"] < 1.5
  
    # 자본금
    temp["자본금 증가율"] = (temp["자본금"] - temp["자본금 1Y lag"]) / temp["자본금 1Y lag"]
    temp["자본금 변동없음"] = temp["자본금 증가율"].abs() < 0.05
    
    # 이익잉여금
    
    temp["이익잉여금이 3년동안 증가"] = (temp["이익잉여금"] > temp["이익잉여금 1Y lag"]) &  (temp["이익잉여금"] > temp["이익잉여금 2Y lag"]) &  (temp["이익잉여금 1Y lag"] > temp["이익잉여금 2Y lag"])

    
    ## 현금흐름표
    
    # 영업활동현금흐름
    temp["영업활동으로인한현금흐름 판별"] = temp["영업활동으로인한현금흐름"] > 0
    temp["3년 중 2년 이상 영업활동으로인한현금흐름 0 초과"] = (temp["영업활동으로인한현금흐름 판별"].rolling(3).sum() > 2)
    
    # 투자활동현금흐름

    temp["투자활동으로인한현금흐름 판별"] = temp["투자활동으로인한현금흐름"] < 0
    temp["3년 중 2년 이상 투자활동으로인한현금흐름 0 미만"] = (temp["투자활동으로인한현금흐름 판별"].rolling(3).sum() > 2)
    
    
    ## 배당
    temp["배당존재"] = temp["배당"] > 0 
    temp["배당이 3년동안 증가"] =(temp["배당"] > temp["배당 1Y lag"]) &  (temp["배당"] > temp["배당 2Y lag"]) &  (temp["배당 1Y lag"] > temp["배당 2Y lag"])

    
    ## 기타
    
    # ROE가 5% 이상
    temp["ROE 5퍼 이상"]  = temp["ROE"] > 0.05
    
    # 추후 많은 지표들 추가
    
    
    temp["Symbol"] = company
    temp = temp.reset_index()
    temp = temp.set_index(["Symbol", "date"])
    
    new_data.append(temp)

# %%
old = pd.DataFrame()
for company_data in new_data:
    old = pd.concat([old, company_data])

# %%
필터조건 = ["매출액 100억 이상", "영업이익 3년동안 0 이상", "영업이익률 3년동안 증가", "매출액 3년동안 증가", "순이익시총비율 0.1이상", 
        "영업이익시총비율 0.1이상","자본잠식 없음", "부채비율 150% 이하", "자본금 변동없음", 
        "이익잉여금이 3년동안 증가","3년 중 2년 이상 영업활동으로인한현금흐름 0 초과",
        "3년 중 2년 이상 투자활동으로인한현금흐름 0 미만","배당존재", "배당이 3년동안 증가","ROE 5퍼 이상"]

# %%
년도별조건 = old[필터조건]

# %%
년도별조건

# %%
년도별조건.to_csv("year_filter.csv", encoding = "ms949")
